# %%
import sys
sys.path.append("..")
from cal_simulation import csv_to_list

# %%
FAQs = csv_to_list("FAQ_with_sim.csv")

# %%
FAQs
# Out:
# ...
#  ...]

# %%
FAQs_common = csv_to_list("public_FAQ.csv")
# Out:
# Traceback (most recent call last):
#
#   File "D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-7-b310f9b16402>", line 1, in <module>
#     FAQs_common = csv_to_list("public_FAQ.csv")
#
#   File "..\cal_simulation.py", line 45, in csv_to_list
#     sim_questions = eval(df.iloc[i]['similiar_question'])
#
#   File "<string>", line 1
#     深圳图书馆什么样的人可以办读书卡？
#                     ^
# SyntaxError: invalid character in identifier

# %%
import pandas as pd
filepath = "public_FAQ.csv"
df = pd.read_csv(filepath)
FAQs = []

# %%
df.iloc[0]['similiar_question']
# Out:
# '深圳图书馆什么样的人可以办读书卡？ 深圳图书馆是面向谁的？'

# %%
df.iloc[0]['similiar_question'].split(" ")
# Out:
# ['深圳图书馆什么样的人可以办读书卡？', '深圳图书馆是面向谁的？']

# %%
" ".join(df.iloc[0]['similiar_question'])
# Out:
# '深 圳 图 书 馆 什 么 样 的 人 可 以 办 读 书 卡 ？'

# %%
df2 = pd.read_csv("FAQ_with_sim.csv")

# %%
df2.iloc[2433]['similiar_question'].split(" ")
# Out:
# ["['中意的理赔怎样跟踪进度？',",
#  "'商业保险的理赔进度查询可以到哪里查？',",
#  "'申请的商保理赔办理进度如何查询？',",
#  "'之前投放了商报理赔，为什么现在还没有消息？',",
#  "'上个月提交的中意人寿保险，但是现在还没处理好，能帮忙查下吗？',",
#  "'商业医疗保险的进度，找哪位问？',",
#  "'商业保险好几天了，为什么都没有信息反馈？',",
#  "'上周提交了商保报销，进度该怎么查询？',",
#  "'提交了商业保险理赔的材料，保险公司没有给到任何回复，在哪里可以查看进度?',",
#  "'医疗报销的进度怎么查询？',",
#  "'中意人寿的商业保险赔付进度如何查询？',",
#  "'商保理赔的进度在哪里查？',",
#  "'想查查商保理赔进度，放入希格玛的理赔箱了，可迟迟没有回复？',",
#  "'我月初申请的商业报销有结果了吗？',",
#  "'我两周之前提交了保险理赔申请，为啥现在还看不到？']"]

# %%
df2.iloc[2433]['similiar_question'].split(',')[2]
# Out:
# str

# %%
a = [('sd','sdv',2),('vsd','sasdv',1),('wsd','sdvs',4)]
a = [('sd','sdv',2),('vsd','sasdv',2),('wsd','sdvs',4)]
